# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3759a9e6-67ea-4ec3-a03a-02f0eff06b15" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3759a9e6-67ea-4ec3-a03a-02f0eff06b15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv("Cutlets (1).csv")
data.head()
# Out:
#    Unit A  Unit B
# 0  6.8090  6.7703
# 1  6.4376  7.5093
# 2  6.9157  6.7300
# 3  7.3012  6.7878
# 4  7.4488  7.1522

# %%
a=data["Unit A"]
b=data["Unit B"]

# %%
stats.ttest_ind(a,b)
# Out:
# TtestResult(statistic=0.7228688704678063, pvalue=0.4722394724599501, df=68.0)

# %% [markdown]
# 2nd question

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import f_oneway

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-a205eb3b-03ed-406d-a120-9ab6f12a0c9f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a205eb3b-03ed-406d-a120-9ab6f12a0c9f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
lab= pd.read_csv("LabTAT (1).csv")
lab.head()
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
lab1=lab["Laboratory 1"]
lab2=lab["Laboratory 2"]
lab3=lab["Laboratory 3"]
lab4=lab["Laboratory 4"]

# %%
f_stat, p_value = f_oneway(lab1, lab2, lab3, lab4)
print("F-statistic:", f_stat)
print("P-value:", p_value)
# Out:
# F-statistic: 118.70421654401437
# P-value: 2.1156708949992414e-57

# %% [markdown]
# question 3

# %%
# !pip install researchpy
from scipy.stats  import chi2_contingency
import researchpy as rp
import numpy as np
import sys

# %%
from statsmodels.stats.proportion import  proportions_chisquare

# %%
male_counts = np.array([50, 142, 131, 70])
female_counts = np.array([550, 351, 480, 350])
total_counts = male_counts + female_counts

# %%
stats, p_value, dof = proportions_chisquare(count=male_counts,
                                      nobs=total_counts)

# %%
print(stats)
print(p_value)
# Out:
# 80.27295426602495
# 2.682172557281901e-17

# %% [markdown]
# question 4

# %%
from scipy.stats import chi2_contingency

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-de58ac4c-86a5-4451-a695-a46bf6a33ea2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de58ac4c-86a5-4451-a695-a46bf6a33ea2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
bulb1=pd.read_csv("Costomer+OrderForm (1).csv")
bulb1.head()
# Out:
#   Phillippines   Indonesia       Malta       India
# 0   Error Free  Error Free   Defective  Error Free
# 1   Error Free  Error Free  Error Free   Defective
# 2   Error Free   Defective   Defective  Error Free
# 3   Error Free  Error Free  Error Free  Error Free
# 4   Error Free  Error Free   Defective  Error Free

# %%
bulb1[bulb1[["Phillippines","Indonesia","Malta","India"]]=="Error Free"] = 1
bulb1[bulb1[["Phillippines","Indonesia","Malta","India"]]=="Defective"] = 0

# %%
bulb1.head()
# Out:
#   Phillippines Indonesia Malta India
# 0            1         1     0     1
# 1            1         1     1     0
# 2            1         0     0     1
# 3            1         1     1     1
# 4            1         1     0     1

# %%
from scipy.stats import chi2

# %%
chi2, p, dof, expected = chi2_contingency(bulb1)

# %%
print(chi2)
print(p)
print(dof)
# Out:
# 112.74730231885849
# 1.0
# 897
